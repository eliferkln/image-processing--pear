# %%
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
import cv2 as cv

# %%
import cv2

# %%
img= cv2.imread('pp.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
edges = cv2.Canny(image=img, threshold1=127 , threshold2=127)

# %%
plt.imshow(edges)

# %%
edges = cv2.Canny(image=img, threshold1=0 , threshold2=255)

# %%
plt.imshow(edges)

# %%
imgg=cv2.blur(img, ksize=(5,5))

# %%
edges = cv2.Canny(image=img, threshold1=100 , threshold2=180)

# %%
plt.imshow(edges)

# %%
imgp= cv2.imread('oo.jpg')

# %%
plt.imshow(imgp)

# %%
edges = cv2.Canny(image=img, threshold1=127 , threshold2=127)

# %%
plt.imshow(edges)

# %%
imgg=cv2.blur(img, ksize=(5,5))

# %%
edges = cv2.Canny(image=img, threshold1=0 , threshold2=250)

# %%
plt.imshow(edges)

# %%
imgpd= cv2.imread('dd.jpg')

# %%
plt.imshow(imgpd)

# %%
imgg=cv2.blur(imgpd, ksize=(5,5))

# %%
edges = cv2.Canny(image=imgpd, threshold1=0 , threshold2=250)

# %%
plt.imshow(edges)
